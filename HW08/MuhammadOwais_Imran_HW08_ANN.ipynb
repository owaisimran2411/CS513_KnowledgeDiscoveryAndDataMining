# %%
# Student Information:
# Name Muhammad Owais Imran
# CWID: 20025554
# HW # 08
# HW Title: Artifical Neural Network (ANN) Classifier

# %% [markdown]
# ## **Library import**

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, LabelEncoder
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical

# %% [markdown]
# ## **Loading CSV File**

# %%
data = pd.read_csv("./MuhammadOwais_Imran_HW08_ANN_Dataset.csv")
data = data.drop(columns=['id'])

# Encoding categorical data (if 'diagnosis' is categorical)
label_encoder = LabelEncoder()
data['diagnosis'] = label_encoder.fit_transform(data['diagnosis'])

# Split features and target variable
X = data.drop(columns=['diagnosis'])
y = data['diagnosis']

# %% [markdown]
# ## **Standardizing Dividing the data into train (70%) and test (30%) split**

# %%
# Normalize/Standardize features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Create a Sequential model
model = Sequential()

# Add an input layer and a hidden layer with 5 nodes
model.add(Dense(units=5, activation='sigmoid', input_dim=X_train.shape[1]))

# Add an output layer (assuming binary classification)
model.add(Dense(units=1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 13/13 [==============================] - 1s 17ms/step - loss: 0.6599 - accuracy: 0.6080 - val_loss: 0.6194 - val_accuracy: 0.7778
# Epoch 2/50
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6134 - accuracy: 0.7864 - val_loss: 0.5750 - val_accuracy: 0.8947
# Epoch 3/50
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5720 - accuracy: 0.8995 - val_loss: 0.5350 - val_accuracy: 0.9474
# Epoch 4/50
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5344 - accuracy: 0.9372 - val_loss: 0.5000 - val_accuracy: 0.9532
# Epoch 5/50
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5013 - accuracy: 0.9397 - val_loss: 0.4681 - val_accuracy: 0.9591
# Epoch 6/50
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4719 - accuracy: 0.9573 - val_loss: 0.4397 - val_accuracy: 0.9649
# Epoch 7/50
# ...

# %% [markdown]
# ## **Predicting Results**

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss}, Test Accuracy: {accuracy}')

predict=model.predict(X_test)
print(predict)
# Out:
# 6/6 [==============================] - 0s 3ms/step - loss: 0.1413 - accuracy: 0.9883
# Test Loss: 0.14133907854557037, Test Accuracy: 0.988304078578949
# 6/6 [==============================] - 0s 3ms/step
# [[0.16691242]
#  [0.89204925]
#  [0.8427202 ]
#  [0.06740711]
#  [0.05795135]
#  [0.8960713 ]
#  [0.89601856]
#  [0.7901657 ]
#  [0.44375065]
#  [0.06706464]
#  [0.11606562]
#  [0.81594867]
#  [0.08392667]
#  [0.6947734 ]
#  [0.06747165]
#  [0.889235  ]
#  [0.0695576 ]
#  [0.05512088]
#  [0.05377899]
#  [0.89521515]
#  [0.23708324]
#  [0.08393478]
#  [0.8960078 ]
#  [0.05601806]
#  [0.06815086]
#  [0.06660396]
#  [0.06965664]
#  [0.07609291]
#  [0.0766862 ]
#  [0.8943364 ]
#  [0.06834642]
#  [0.05819133]
#  [0.06458175]
#  [0.08252843]
#  [0.05817108]
#  [0.06541023]
#  [0.67280173]
#  [0.06432921]
#  [0.88773686]
#  [0.18110465]
#  [0.0578531 ]
#  [0.86418456]
#  [0.07789069]
#  [0.06552941]
#  [0.08330984]
#  [0.10087988]
#  [0.06076668]
#  [0.05817247]
#  [0.11820389]
# ...
